# %%
import os
import time
import random
import chess
import chess.svg
import pickle
import cProfile
import numpy as np
import ipywidgets as wg
import tensorflow as tf

from enum import Enum, auto
from typing import Union
from collections import Counter, deque
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2
from IPython.display import display, clear_output

# %%
# Constants
# Visualizing board
BOARD_SIZE = 500    # 500 * 500 pixel^2 board.

PIECES_TO_PROMOTE = 'qrnb'
COLS = 'abcdefgh'
ROWS = list(range(1, 9))
BOARD = np.array([[f'{col}{row}' for col in COLS] for row in ROWS[::-1]])
flat_board = BOARD.flatten()

# Piece maps
PIECE_MAP = {'p': -1, 'r': -5, 'n': -4, 'b': -3, 'q': -9, 'k': -10, '.': 0}
PIECE_MAP = PIECE_MAP | {piece.upper(): piece_id * -1 for piece, piece_id in PIECE_MAP.items()}

# There are some illegal moves here, fix it later?
all_moves = {f'{m1}{m2}' for m1 in flat_board for m2 in flat_board if m1 != m2}

print(len(all_moves))
# Out:
# 4032

# %%
def vertical_moves(pos1):
    for row in ROWS:
        pos2 = pos1[0] + str(row)
        if pos1 != pos2:
            yield pos1 + pos2


def horizontal_moves(pos1):
    # Castling is included in the horizontal movement.
    # e1c1, e1g1 are white castling moves and e8c8 and e8g8 are black castling moves.
    for col in COLS:
        pos2 = col + pos1[1]
        if pos1 != pos2:
            yield pos1 + pos2


def diagonal_moves(pos1):
    r, c = np.where(BOARD == pos1)
    r, c = r[0], c[0]
    
    row_shifter = col_shifter = range(-8, 8, 1)
    for k in [1, -1]:
        # k = 1 means top left to bottom right diagonal and 
        #    -1 means top right to bottom left diagonal
        for i, j in zip(row_shifter, col_shifter):
            rr = r + k * i
            cc = c + j
            if 0 <= rr < 8 and 0 <= cc < 8 and (r, c) != (rr, cc):
                yield pos1 + BOARD[rr, cc]
                

def knight_moves(pos1):
    r, c = np.where(BOARD == pos1)
    r, c = r[0], c[0]
    
    for k in range(2):
        for i in [-2, 2]:       # Two horizontal or vertical move
            for j in [-1, 1]:   # One vertical or horizontal move
                
                if k: rr, cc = r + i, c + j   # 2 horizontal then 1 vertical move
                else: rr, cc = r + j, c + i   # 1 horizontal then 2 vertical move

                if 0 <= rr < 8 and 0 <= cc < 8 and (r, c) != (rr, cc):
                    yield pos1 + BOARD[rr, cc]
    
    # for j in [-2, 2]:
    #     for i in [-1, 1]:
    #         rr, cc = r + i, c + j
    #         if 0 <= rr < 8 and 0 <= cc < 8 and (r, c) != (rr, cc):
    #             yield pos1 + BOARD[rr, cc]


def promotion_moves(pos1):
    if not pos1[1] in {'2', '7'}:
        return
    
    ri = COLS.index(pos1[0])
    pos2_col = '1' if pos1[1] == '2' else '8'
    for i in [-1, 0, 1]:
        col_index = ri + i
        if 0 <= col_index < 8:
            for piece in PIECES_TO_PROMOTE:
                for piece2 in [piece, piece.upper()]:   # Hack: piece type was creating problems. Fix this later.
                    # piece = piece.upper() if pos1[1] == '2' else piece
                    yield pos1 + COLS[col_index] + pos2_col + piece2
           
def get_all_legal_moves():      
    all_legal_moves = set()

    for pos1 in flat_board:
        unions_of_moves = set(vertical_moves(pos1)) | set(horizontal_moves(pos1)) | \
            set(diagonal_moves(pos1)) | set(knight_moves(pos1)) | set(promotion_moves(pos1))
            
        all_legal_moves.update(unions_of_moves)

    len(all_legal_moves)
    return dict(zip(all_legal_moves, range(len(all_legal_moves))))

    ALL_LEGAL_MOVES = get_all_legal_moves

# %%
print(list(vertical_moves('a2')))
print(list(horizontal_moves('a2')))
print(list(diagonal_moves('a2')))
print(list(knight_moves('c4'))) 
print(list(promotion_moves('a2')))
print(list(promotion_moves('g7')))
# Out:
# ['a2a1', 'a2a3', 'a2a4', 'a2a5', 'a2a6', 'a2a7', 'a2a8']
# ['a2b2', 'a2c2', 'a2d2', 'a2e2', 'a2f2', 'a2g2', 'a2h2']
# ['a2b1', 'a2b3', 'a2c4', 'a2d5', 'a2e6', 'a2f7', 'a2g8']
# ['c4a5', 'c4a3', 'c4e5', 'c4e3', 'c4b6', 'c4d6', 'c4b2', 'c4d2']
# ['a2a1q', 'a2a1Q', 'a2a1r', 'a2a1R', 'a2a1n', 'a2a1N', 'a2a1b', 'a2a1B', 'a2b1q', 'a2b1Q', 'a2b1r', 'a2b1R', 'a2b1n', 'a2b1N', 'a2b1b', 'a2b1B']
# ['g7f8q', 'g7f8Q', 'g7f8r', 'g7f8R', 'g7f8n', 'g7f8N', 'g7f8b', 'g7f8B', 'g7g8q', 'g7g8Q', 'g7g8r', 'g7g8R', 'g7g8n', 'g7g8N', 'g7g8b', 'g7g8B', 'g7h8q', 'g7h8Q', 'g7h8r', 'g7h8R', 'g7h8n', 'g7h8N', 'g7h8b', 'g7h8B']

# %%
BOARD
# Out:
# array([['a8', 'b8', 'c8', 'd8', 'e8', 'f8', 'g8', 'h8'],
#        ['a7', 'b7', 'c7', 'd7', 'e7', 'f7', 'g7', 'h7'],
#        ['a6', 'b6', 'c6', 'd6', 'e6', 'f6', 'g6', 'h6'],
#        ['a5', 'b5', 'c5', 'd5', 'e5', 'f5', 'g5', 'h5'],
#        ['a4', 'b4', 'c4', 'd4', 'e4', 'f4', 'g4', 'h4'],
#        ['a3', 'b3', 'c3', 'd3', 'e3', 'f3', 'g3', 'h3'],
#        ['a2', 'b2', 'c2', 'd2', 'e2', 'f2', 'g2', 'h2'],
#        ['a1', 'b1', 'c1', 'd1', 'e1', 'f1', 'g1', 'h1']], dtype='<U2')

# %%
class QType(Enum):
    DQN = auto()
    TABULAR = auto()

# %%
class DeepQNetwork:
    """Using a Convolutional Neural Network Architecture."""
    def __init__(self, epochs: int = 10, batch_size: int = 100):
        self.name = 'cnn_chessRL'

        self.optimizer = keras.optimizers.Adam(learning_rate=0.00025, clipnorm=1.0)
        self.loss_function = keras.losses.Huber()
        self.epochs = epochs
        self.batch_size = batch_size

        self.training_count = 0

        self.model = self.create_model(batch_size=self.batch_size)
        self.predictor_model = self.create_model(batch_size=1) 
        self.predictor_model.set_weights(self.model.get_weights())
        
        self.frozen_func = None
        self.save_as_function(self.predictor_model)
        self.load_frozen_graph()
    
    def __repr__(self):
        return str(self.model.summary())
    
    def create_model(self, batch_size: int):
        input_layer = layers.Input(shape=(8, 8, 1), batch_size=batch_size)
        
        hidden_layer_1 = layers.Conv2D(32, (3, 3), strides=1, activation='relu')(input_layer)
        hidden_layer_2 = layers.Conv2D(64, (3, 3), strides=1, activation='relu')(hidden_layer_1)
        hidden_layer_3 = layers.Conv2D(64, (2, 2), strides=1, activation='relu')(hidden_layer_2)
        
        hidden_layer_4 = layers.Flatten()(hidden_layer_3)
        hidden_layer_5 = layers.Dense(512, activation='relu')(hidden_layer_4)
        
        output_layer = layers.Dense(len(ALL_LEGAL_MOVES), activation='linear')(hidden_layer_5)
        
        model = keras.Model(inputs=input_layer, outputs=output_layer)

        if batch_size != 1:
            model.compile(optimizer=self.optimizer, loss=self.loss_function, metrics=['accuracy'])

        return model
    
    def train(self, features_and_labels, save_path):
        """Features is board state and the labels is the action q values."""

        features, labels = list(zip(*features_and_labels))
        features = np.array(features)
        labels = np.array(labels)

        self.model.fit(features, labels, epochs=self.epochs, batch_size=self.batch_size, shuffle=True)

        self.model.save(save_path)
        self.predictor_model.set_weights(self.model.get_weights())
        self.save_as_function(self.predictor_model)
        self.load_frozen_graph()

        self.training_count += 1
    
    @staticmethod 
    def save_as_function(model):
       # Convert Keras model to ConcreteFunction
        full_model = tf.function(lambda x: model(x))
        full_model = full_model.get_concrete_function(tf.TensorSpec(model.inputs[0].shape, model.inputs[0].dtype))

        # Get frozen ConcreteFunction
        frozen_func = convert_variables_to_constants_v2(full_model)
        frozen_func.graph.as_graph_def()

        # Save frozen graph from frozen ConcreteFunction to hard drive
        tf.io.write_graph(graph_or_graph_def=frozen_func.graph, logdir="./frozen_models", name="frozen_graph.pb", as_text=False) 
    
    @staticmethod 
    def wrap_frozen_graph(graph_def, inputs, outputs, print_graph=False):
        _imports_graph_def = lambda: tf.compat.v1.import_graph_def(graph_def, name="")
        wrapped_import = tf.compat.v1.wrap_function(_imports_graph_def, [])
        import_graph = wrapped_import.graph

        return wrapped_import.prune(tf.nest.map_structure(import_graph.as_graph_element, inputs), 
                                    tf.nest.map_structure(import_graph.as_graph_element, outputs))
 
    def load_frozen_graph(self):
        with tf.io.gfile.GFile("./frozen_models/frozen_graph.pb", "rb") as f:
            graph_def = tf.compat.v1.GraphDef()
            graph_def.ParseFromString(f.read())
        self.frozen_func = self.wrap_frozen_graph(graph_def=graph_def, inputs=["x:0"], outputs=["Identity:0"], print_graph=True)
        
    def get_Q(self, state):
        state = tf.convert_to_tensor(state, dtype=tf.float32)
        state = tf.reshape(state, self.predictor_model.inputs[0].shape)
        
        return self.frozen_func(state)[0][0]

# %%
# Constants
TRAIN_INTERVAL = 2000


class ChessRL:
    def __init__(self, init_reward=None, q_method: QType = QType.DQN, experience_replay_size_threshold: int = 100000, 
                 saved_q: Union[str, os.PathLike, None] = 'dqn_py_chess'):
        
        # Initializing the board
        self.board = chess.Board()
        self.temp_board = chess.Board()
        
        # Initializing the rewards
        self._init_reward = init_reward
        self.reward_lb = -1
        self.reward_ub = 1
        
        # Initialize Q
        self.q_architecture = q_method
        self.dqn_model_path = saved_q
        self.initialize_q(saved_q)
        
        # Experience replay stuff
        self.experience_replay_visits = 0
        self.experience_replay = deque(maxlen=experience_replay_size_threshold)
        self.experience_replay_size_threshold = experience_replay_size_threshold
        
        # All possible actions (Including illegal ones)
        self.action_space_size = len(ALL_LEGAL_MOVES)
        
        # Q cache: Will change every time network is trained again
        self.q_cache = {}
        
        # Extra informations to determine terminal state
        self._sub_episode = None
        self._max_episode_length = None
        
    def initialize_q(self, saved_q: Union[str, os.PathLike, None] = None):

        if self.q_architecture == QType.DQN:
            # Initializing the Deep Q network
            self.dqn = DeepQNetwork()
            # model = self.load_q_from_file(saved_q)
            # if model: self.dqn._model = model

        elif self.q_architecture == QType.TABULAR:
            # Load weights from the already trained model
            self._Q = self.load_q_from_file(saved_q)
        else:
            raise NotImplementedError("Q type not implemented.")
    
    @property
    def init_reward(self):
        if not self._init_reward:
            self._init_reward = lambda: np.random.uniform(-1, 1)
        return self._init_reward()
    
    # Showing the board
    def show_board(self, board=None, size=BOARD_SIZE):
        if not board:
            board = self.board
            
        display(chess.svg.board(board, size=size))
        
    def game_real_time(self):
        """Displays the board and keeps the board positions"""
        while True:
            board, action = yield
            clear_output()
            display(chess.svg.board(board, size=BOARD_SIZE, lastmove=chess.Move.from_uci(action)))
    
    def display_next_board(self, action):
        gamert = self.game_real_time()
        next(gamert)
        gamert.send((self.board, action))
        
    def show_game(self, states, size=BOARD_SIZE):
        """Fix later"""
        t_board = chess.Board()
        boards = []
        for state in states:
            t_board.set_fen(state)
            boards.append(chess.svg.board(t_board, size=size))
        
        wg.interact(lambda x: display(boards[x]), x=wg.IntSlider(min=0, max=len(states)-1, step=1))
        
        del t_board
    
    # State space stuff
    def reset_to_initial_state(self):
        self.board.reset()
    
    @property
    def current_state(self):
        return str(self.board.fen())

    @property
    def turn(self):
        return "white" if self.board.turn else "black"
    
    @property 
    def terminal(self):
        return self.board.is_game_over()
    
    def simplify_state(self, state: str) -> str:
        """Returns only the position of pieces, everything else is removed from fen."""
        self.temp_board.set_fen(state)
        return f"{self.temp_board}".replace(' ', '').replace('\n', '')
    
    def num_rep_state(self, state: str) -> np.array:
        """
        Returns the numerical representation of the board state. 
        Sum can be used for static evaluation of the board.
        This will be used as the input to the neural net.
        """
        state = self.simplify_state(state)
        return np.array([PIECE_MAP[piece] for piece in state]).reshape(8, 8)
   
    # Action stuff 
    def num_rep_action_q_values(self, state: str, action: str = None, value: float = None):
        """
        Returns the Q values for the actions at a given state. 
        This will be used as the label for a given state to train the neural net.
        """
        one_hot_action_Qs = np.zeros(len(ALL_LEGAL_MOVES))
        
        action_qs = {ALL_LEGAL_MOVES[action]: self.normalized_Q(state, action) 
                     for action in self.possible_actions(state)}
        action_qs[ALL_LEGAL_MOVES[action]] = value

        np.put(one_hot_action_Qs, action_qs.keys(), action_qs.values())
        return one_hot_action_Qs
    
    def possible_actions(self, state):
        self.temp_board.set_fen(state)
        return [str(move) for move in self.temp_board.legal_moves]
    
    def choose_greedy_action(self, epsilon: float) -> bool:
        return True if np.random.uniform(0, 1) < (1 - epsilon) else False
        
    def epsilon_greedy_action(self, state, epsilon):
        if self.choose_greedy_action(epsilon):
            return self.argmax_Q(state)
        else:
            actions = self.possible_actions(state)
            random_action_index = random.randint(0, len(actions)-1)
            return actions[random_action_index]
            
    def take_action(self, action: str):
        # Taking action
        self.board.push_uci(action)
        
        # Get the new state because of taken action
        new_state = self.current_state
        
        # Get the reward because of the taken action
        reward = self.reward
        
        return (new_state, reward)
    
    # Reward Stuff
    @property
    def reward(self):
        if self.terminal:
            if self.board.result in ["1-0", "0-1"]:
                return 1
            else:
                return -1
        # if self.board.is_fivefold_repetition():
        #     return -5
        # if self.board.can_claim_threefold_repetition():
        #     return -3
        return 0
        
    
    # Q stuff
    def update_q_cache(self, state, simple_state):
        numerical_state = self.num_rep_state(state)
        normalized_q = self.dqn.get_Q(numerical_state)
        self.q_cache[simple_state] = self.denormalize_Q(normalized_q)
        
    def Q(self, state, action):
        """
        Return the Q values from the Deep Q Network if DQN is used otherwise return q values from the lookup table.
        """
        action = ALL_LEGAL_MOVES[action]
        simple_state = self.simplify_state(state) if isinstance(state, dict) else state
        if simple_state in self.q_cache:
            return self.q_cache[simple_state][action]
        
        if self.q_architecture == QType.DQN:
            # DQN will predict the q values
            self.update_q_cache(state, simple_state)
            return self.q_cache[simple_state][action]

        else: 
            # If q architecture is not a nn then q values will be obtained from the q lookup table.
            if simple_state not in self._Q:
                for a in self.possible_actions(state):
                    self.set_Q(state=state, action=a, value=self.init_reward)
                    
            elif action not in self._Q[simple_state]:
                self._Q[simple_state][action] = self.init_reward
                
            return self._Q[simple_state][action]
    
    def normalized_Q(self, state, action):
        return (self.Q(state, action) - self.reward_lb) / (self.reward_ub - self.reward_lb)
    
    def denormalize_Q(self, normalized_q_value):
        return normalized_q_value * (self.reward_ub - self.reward_lb)

    def set_Q(self, state, action, value=None):
        
        if self.q_architecture == QType.DQN:
            # Keep accumulating data
            state_feature = self.num_rep_state(state)
            action_label = self.num_rep_action_q_values(state, action, value)
            self.experience_replay.append((state_feature, action_label))
            self.experience_replay_visits += 1

            # Train dqn with this accumulated data if have enough data
            train_interval_ok = not self.experience_replay_visits % TRAIN_INTERVAL
            have_enough_training_data = len(self.experience_replay) == self.experience_replay_size_threshold

            if train_interval_ok and have_enough_training_data:            
                # Train if enough data accumulated
                self.dqn.train(self.experience_replay, save_path=self.dqn_model_path)
                self.q_cache = {}

        else:
            state = self.simplify_state(state)
            self._Q.setdefault(state, {})
            self._Q[state][action] = value
        
    def max_Qa(self, state):
        return max([(self.Q(state, action), action) for action in self.possible_actions(state)])
        
    def max_Q(self, state):
        """Returns the max Q value for the best action."""
        return self.max_Qa(state)[0]
    
    def argmax_Q(self, state):
        """Returns the best action for which max Q was found for the input state."""
        return self.max_Qa(state)[1]
        

    # Learning Stuff
    def q_learning(self, episodes, epsilon, alpha, gamma, max_episode_length, show_interval):
        # Initialize progress bar
        f = wg.IntProgress(min=0, max=episodes)
        display(f)
        
        for episode in range(episodes):
            
            # Show progress
            f.value = episode

            # Initialize a state
            self.reset_to_initial_state()
            state = self.current_state
            
            # Storing just to visualize games
            play_states = [state]
            
            while not self.terminal and len(play_states) <= max_episode_length:
                
                # Select epsilon greedy action
                action = self.epsilon_greedy_action(state, epsilon)
                
                # Take action get reward and new state
                new_state, reward = self.take_action(action)
                
                # Storing just to visualize games
                play_states.append(new_state)
                
                if not self.terminal:
                    # Q-learning update
                    off_policy_td = (reward + gamma * self.max_Q(new_state) - self.Q(state, action))
                    new_Q_sa = self.Q(state, action) + alpha * off_policy_td
                else:
                    new_Q_sa = reward
                
                # Update the DQN model or the Q lookup table
                self.set_Q(state, action, new_Q_sa)
                
                # Update the state
                state = new_state        
            
            if episode % show_interval == 0:
                print(len(play_states))
                self.show_game(states=play_states)
                del play_states
        
        self.save_q_to_file('dqn')
        
        
    def sarsa(self, episodes, epsilon, alpha, gamma, max_episode_length, show_interval):    
        # Initialize progress bar
        f = wg.IntProgress(min=0, max=episodes)
        display(f)
        
        for episode in range(episodes):
            
            # Show progress
            f.value = episode

            # Initialize a state
            self.reset_to_initial_state()
            state = self.current_state
            
            # Storing just to visualize a game
            play_states = [state]

            # Select epsilon greedy action
            action = self.epsilon_greedy_action(state, epsilon)
            
            while not self.terminal and len(play_states) <= max_episode_length:
                
                # Take action get reward and new state
                new_state, reward = self.take_action(action)
                
                # Storing just to visualize games
                play_states.append(new_state)
                
                if not self.terminal:
                    # SARSA update
                    new_action = self.epsilon_greedy_action(new_state, epsilon)
                    on_policy_td = (reward + gamma * self.Q(new_state, new_action) - self.Q(state, action))
                    new_Q_sa = self.Q(state, action) + alpha * on_policy_td
                else:
                    new_Q_sa = reward
                
                # Update the DQN model or the Q lookup table
                self.set_Q(state, action, new_Q_sa)
                
                # Update state and action
                state = new_state
                action = new_action
            
            if episode % show_interval == 0:
                print(len(play_states))
                self.show_game(states=play_states)
                del play_states
        
        self.save_q_to_file('sarsa_nn')

    
    def truncated_rollout(self, episodes, epsilon, alpha, gamma, truncation_depth, max_episode_length, show_interval):
        pass
    
    def monte_carlo_tree_search(self, episodes, epsilon, alpha, gamma, truncation_depth, max_episode_length, show_interval):    
        pass
           
           
    # Heuristic policy
    def minimax_with_alpha_beta_pruning(self):
        pass
    
    # Static Evaluation of game state
    def remaining_materials(self, state):
        return Counter(str(self.simplify_state(state)))
    
    def material_score(self, state):
        weighted_materials = self.num_rep_state(state)

        # Replace the knights scores, which is set to 4, to 3
        weighted_materials[weighted_materials == 4] = 3

        # Replace the kings scores from 10 to 200 according to Claude Shannon's formulation 
        weighted_materials[weighted_materials == 10] = 200

        return np.sum(weighted_materials)
    
    def mobility_score(self, state):
        """
        Returns the mobility score at state s 
        mobility score(s) = current players legal moves(s) - opponents legal moves(s)
        """
        # Create a temporary board to check the legal moves number at different states 
        # without affecting the actual game.
        self.temp_board.set_fen(state)
        
        # Get the current player's number legal moves
        current_player_moves = len(self.temp_board.legal_moves)

        # Pass control to the opponent
        self.temp_board.push(chess.Move.null())

        # Get the opponent player's number of legal move 
        opponents_moves = len(self.temp_board.legal_moves)
        
        return current_player_moves - opponents_moves
        
    def static_analysis_of_board(self, state):
        """Returns the positional evaluation of the board."""
        return self.material_score(state) + self.mobility_score(state) 
    
    # Saving and loading q values 
    def save_q_to_file(self, filename: str):
        filename += 'py_chess'
        if self.q_architecture == QType.DQN:
            self.dqn.model.save(filename)

        elif self.q_architecture == QType.TABULAR: 
            with open(filename, 'wb') as file:
                pickle.dump(self._Q, file, protocol=pickle.HIGHEST_PROTOCOL)

        else:
            raise NotImplementedError("Unknown Q architecture")
        
    def load_q_from_file(self, filename: str):

        if self.q_architecture == QType.DQN:
            dqn_model = None
            try:
                dqn_model = keras.models.load_model(filename)
            except FileNotFoundError:
                print('File does not exist')
            except OSError:
                print('File does not exist')

            return dqn_model

        elif self.q_architecture == QType.TABULAR:
            q_lookup_table = {}
            try:
                with open(filename, 'rb') as file:
                    q_lookup_table = pickle.load(file)
            except FileNotFoundError:
                pass
            return q_lookup_table

        else:
            raise NotImplementedError("Unknown Q architecture")
    
    def play(self):
        self.reset_to_initial_state()
        state = self.current_state
        states = [state]
        while not self.terminal:
            action = self.argmax_Q(state)
            state, _ = self.take_action(action)
            states.append(state)
        self.show_game(states=states)

# %%
with cProfile.Profile() as pr:
    C = ChessRL(saved_q='dqn_py_chess', experience_replay_size_threshold=1000)
    C.q_learning(episodes=2, epsilon=0.5, alpha=0.1, gamma=0.95, max_episode_length=200, show_interval=500)
    # C.sarsa(episodes=10000, epsilon=0.5, alpha=0.1, gamma=0.95, max_episode_length=200, show_interval=500)
    # C.play()
# Out:
# IntProgress(value=0, max=2)
# 201
# interactive(children=(IntSlider(value=0, description='x', max=200), Output()), _dom_classes=('widget-interact'…
# INFO:tensorflow:Assets written to: dqn_pychess\assets

# %%
from pprint import pprint
pprint(pr.print_stats())
# Out:
#          11855584 function calls (11473706 primitive calls) in 10.040 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1202    0.001    0.000    0.047    0.000 193473104.py:101(terminal)
#       801    0.003    0.000    0.161    0.000 193473104.py:105(simplify_state)
#       801    0.003    0.000    0.174    0.000 193473104.py:110(num_rep_state)
#       801    0.003    0.000    0.003    0.000 193473104.py:117(<listcomp>)
#       400    0.033    0.000    3.114    0.008 193473104.py:120(num_rep_action_q_values)
#      1200    0.004    0.000    0.305    0.000 193473104.py:133(possible_actions)
#      1200    0.019    0.000    0.183    0.000 193473104.py:135(<listcomp>)
#       400    0.001    0.000    0.007    0.000 193473104.py:137(choose_greedy_action)
#       400    0.001    0.000    1.560    0.004 193473104.py:140(epsilon_greedy_action)
#       400    0.001    0.000    0.078    0.000 193473104.py:148(take_action)
#       400    0.000    0.000    0.016    0.000 193473104.py:161(reward)
#       401    0.002    0.000    0.645    0.002 193473104.py:176(update_q_cache)
#     29886    0.044    0.000    5.441    0.000 193473104.py:181(Q)
#     11462    0.040    0.000    2.925    0.000 193473104.py:206(normalized_Q)
#       401    0.001    0.000    0.018    0.000 193473104.py:209(denormalize_Q)
#       400    0.003    0.000    3.208    0.008 193473104.py:212(set_Q)
#       610    0.009    0.000    4.561    0.007 193473104.py:235(max_Qa)
#       610    0.011    0.000    3.426    0.006 193473104.py:236(<listcomp>)
#       400    0.001    0.000    3.060    0.008 193473104.py:238(max_Q)
#       210    0.000    0.000    1.502    0.007 193473104.py:242(argmax_Q)
#         1    0.008    0.008    9.712    9.712 193473104.py:248(q_learning)
#         1    0.000    0.000    0.330    0.330 193473104.py:38(initialize_q)
#         1    0.000    0.000    0.944    0.944 193473104.py:399(save_q_to_file)
#         1    0.000    0.000    0.330    0.330 193473104.py:6(__init__)
#         1    0.004    0.004    0.586    0.586 193473104.py:77(show_game)
#         1    0.000    0.000    0.001    0.001 193473104.py:85(<lambda>)
#         2    0.000    0.000    0.000    0.000 193473104.py:90(reset_to_initial_state)
#       402    0.001    0.000    0.042    0.000 193473104.py:93(current_state)
#         2    0.000    0.000    0.086    0.043 4190026591.py:24(create_model)
#         1    0.000    0.000    0.330    0.330 4190026591.py:3(__init__)
#         1    0.001    0.001    0.135    0.135 4190026591.py:63(save_as_function)
#         1    0.000    0.000    0.067    0.067 4190026591.py:76(wrap_frozen_graph)
#         1    0.000    0.000    0.011    0.011 4190026591.py:78(<lambda>)
#         1    0.000    0.000    0.104    0.104 4190026591.py:85(load_frozen_graph)
#       401    0.004    0.000    0.543    0.001 4190026591.py:93(get_Q)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(prod)
#         9    0.000    0.000    0.000    0.000 <decorator-gen-2>:1(__call__)
#         1    0.000    0.000    0.000    0.000 <decorator-gen-3>:1(__call__)
#       3/2    0.000    0.000    0.008    0.004 <decorator-gen-4>:1(__call__)
#         1    0.000    0.000    0.000    0.000 <decorator-gen-5>:1(__call__)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1002(_find_and_load)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1018(_gcd_import)
#        54    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#        18    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:112(release)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:152(__init__)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:156(__enter__)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:160(__exit__)
#        18    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:166(_get_module_lock)
#        18    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:185(cb)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:203(_lock_unlock_module)
#         4    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:220(_call_with_frames_removed)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:231(_verbose_message)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:35(_new_module)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:351(__init__)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:385(cached)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:398(parent)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:406(has_location)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:486(_init_module_attrs)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:558(module_from_spec)
#        18    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:58(__init__)
#        18    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:87(acquire)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:948(_sanity_check)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1017(path_stats)
#         2    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1022(_cache_bytecode)
#         2    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1027(set_data)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:104(_path_isdir)
#         2    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:120(_write_atomic)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1564(_get_supported_file_loaders)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:301(cache_from_source)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:431(_get_cached)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:443(_calc_mode)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:46(_pack_uint32)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:463(_check_name_wrapper)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:598(_code_to_timestamp_pyc)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:62(_path_join)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:636(spec_from_file_location)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:64(<listcomp>)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:68(_path_split)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:773(is_package)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:781(create_module)
#         2    0.000    0.000    0.003    0.002 <frozen importlib._bootstrap_external>:784(exec_module)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:80(_path_stat)
#         2    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:848(source_to_code)
#         2    0.000    0.000    0.003    0.002 <frozen importlib._bootstrap_external>:856(get_code)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:90(_path_is_mode_type)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:946(__init__)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:971(get_filename)
#         4    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:976(get_data)
#        14    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#    157110    0.032    0.000    0.032    0.000 ElementTree.py:1049(_escape_attrib)
#       201    0.001    0.000    0.393    0.002 ElementTree.py:1092(tostring)
#      8438    0.021    0.000    0.054    0.000 ElementTree.py:1334(XML)
#       201    0.000    0.000    0.000    0.000 ElementTree.py:536(__init__)
#       201    0.001    0.000    0.392    0.002 ElementTree.py:693(write)
#       402    0.002    0.000    0.005    0.000 ElementTree.py:758(_get_writer)
#       201    0.057    0.000    0.090    0.000 ElementTree.py:810(_namespaces)
#      5658    0.001    0.000    0.001    0.000 ElementTree.py:821(add_qname)
# 39316/201    0.160    0.000    0.296    0.001 ElementTree.py:871(_serialize_xml)
#         1    0.000    0.000    0.000    0.000 __autograph_generated_fileg2mtbn5_.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 __autograph_generated_fileg2mtbn5_.py:2(outer_factory)
#         1    0.000    0.000    0.000    0.000 __autograph_generated_fileg2mtbn5_.py:29(else_body)
#         1    0.000    0.000    0.000    0.000 __autograph_generated_fileg2mtbn5_.py:37(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 __autograph_generated_fileg2mtbn5_.py:5(inner_factory)
#         1    0.000    0.000    0.017    0.017 __autograph_generated_fileg2mtbn5_.py:7(tf___wrapped_model)
#         1    0.000    0.000    0.000    0.000 __autograph_generated_filejdrfyerv.py:5(inner_factory)
#         1    0.000    0.000    0.016    0.016 __autograph_generated_filejdrfyerv.py:6(<lambda>)
#         1    0.000    0.000    0.000    0.000 __autograph_generated_filet6uedxxo.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 __autograph_generated_filet6uedxxo.py:3(outer_factory)
#         1    0.000    0.000    0.000    0.000 __autograph_generated_filet6uedxxo.py:7(inner_factory)
#         1    0.000    0.000    0.005    0.005 __autograph_generated_filet6uedxxo.py:9(tf__signature_wrapper)
#         1    0.000    0.000    0.000    0.000 __init__.py:1060(flush)
#         1    0.000    0.000    0.001    0.001 __init__.py:1071(emit)
#         9    0.000    0.000    0.000    0.000 __init__.py:109(import_module)
#       801    0.029    0.000    0.078    0.000 __init__.py:1129(__str__)
#         1    0.000    0.000    0.000    0.000 __init__.py:119(getLevelName)
#        17    0.000    0.000    0.000    0.000 __init__.py:1276(disable)
#        60    0.000    0.000    0.001    0.000 __init__.py:130(serialize)
#       400    0.001    0.000    0.001    0.000 __init__.py:1308(__init__)
#     26420    0.003    0.000    0.003    0.000 __init__.py:131(square_file)
#        24    0.000    0.000    0.000    0.000 __init__.py:135(deserialize)
#     17611    0.002    0.000    0.002    0.000 __init__.py:135(square_rank)
#      6094    0.042    0.000    0.067    0.000 __init__.py:1372(_clear_cache)
#         3    0.000    0.000    0.000    0.000 __init__.py:1396(__init__)
#      1200    0.001    0.000    0.001    0.000 __init__.py:1416(legal_moves)
#      6094    0.003    0.000    0.072    0.000 __init__.py:1417(setLevel)
#         5    0.000    0.000    0.000    0.000 __init__.py:1420(reset)
#         5    0.000    0.000    0.000    0.000 __init__.py:1430(reset_board)
#         1    0.000    0.000    0.001    0.001 __init__.py:1436(info)
#      2207    0.002    0.000    0.002    0.000 __init__.py:1456(clear_stack)
#        56    0.000    0.000    0.001    0.000 __init__.py:146(get)
#     39356    0.034    0.000    0.075    0.000 __init__.py:1479(generate_pseudo_legal_moves)
#        82    0.000    0.000    0.000    0.000 __init__.py:1497(log)
#        12    0.000    0.000    0.000    0.000 __init__.py:1546(generate_pseudo_legal_ep)
#         1    0.000    0.000    0.000    0.000 __init__.py:1550(makeRecord)
#         1    0.000    0.000    0.001    0.001 __init__.py:1565(_log)
#         1    0.000    0.000    0.001    0.001 __init__.py:1591(handle)
#       400    0.001    0.000    0.004    0.000 __init__.py:1593(is_into_check)
#       400    0.001    0.000    0.003    0.000 __init__.py:1609(is_pseudo_legal)
#         1    0.000    0.000    0.001    0.001 __init__.py:1645(callHandlers)
#       400    0.001    0.000    0.008    0.000 __init__.py:1658(is_legal)
#      4011    0.001    0.000    0.001    0.000 __init__.py:1661(is_variant_end)
#        17    0.000    0.000    0.000    0.000 __init__.py:1675(getEffectiveLevel)
#        83    0.000    0.000    0.000    0.000 __init__.py:1689(isEnabledFor)
#      1202    0.003    0.000    0.046    0.000 __init__.py:1694(is_game_over)
#      3047    0.000    0.000    0.000    0.000 __init__.py:175(value)
#      1202    0.002    0.000    0.004    0.000 __init__.py:1785(is_insufficient_material)
#      6094    0.002    0.000    0.081    0.000 __init__.py:179(value)
#      2404    0.001    0.000    0.002    0.000 __init__.py:1790(<genexpr>)
#      1202    0.001    0.000    0.001    0.000 __init__.py:1792(has_insufficient_material)
#      1202    0.000    0.000    0.000    0.000 __init__.py:1827(is_seventyfive_moves)
#       100    0.000    0.000    0.001    0.000 __init__.py:183(dumps)
#      6094    0.005    0.000    0.079    0.000 __init__.py:184(_update_logging_levels)
#      1202    0.001    0.000    0.016    0.000 __init__.py:1840(is_fivefold_repetition)
#      1202    0.015    0.000    0.015    0.000 __init__.py:1914(is_repetition)
#      6094    0.001    0.000    0.002    0.000 __init__.py:193(_checkLevel)
#       400    0.000    0.000    0.001    0.000 __init__.py:1963(_board_state)
#        50    0.000    0.000    0.000    0.000 __init__.py:1966(_push_capture)
#       400    0.003    0.000    0.007    0.000 __init__.py:1969(push)
#       473    0.000    0.000    0.000    0.000 __init__.py:202(lsb)
#        15    0.000    0.000    0.000    0.000 __init__.py:206(__getattr__)
#      7603    0.002    0.000    0.003    0.000 __init__.py:211(msb)
#     75033    0.017    0.000    0.021    0.000 __init__.py:214(scan_reversed)
#       402    0.002    0.000    0.004    0.000 __init__.py:2145(castling_xfen)
#       484    0.000    0.000    0.000    0.000 __init__.py:2162(<genexpr>)
#       402    0.000    0.000    0.000    0.000 __init__.py:2178(has_legal_en_passant)
#      6111    0.002    0.000    0.003    0.000 __init__.py:218(_acquireLock)
#       402    0.001    0.000    0.041    0.000 __init__.py:2182(fen)
#      2202    0.012    0.000    0.215    0.000 __init__.py:2221(set_fen)
#        27    0.000    0.000    0.000    0.000 __init__.py:224(popcount)
#      6111    0.002    0.000    0.002    0.000 __init__.py:227(_releaseLock)
#      2202    0.003    0.000    0.005    0.000 __init__.py:2314(_set_castling_fen)
#       402    0.002    0.000    0.040    0.000 __init__.py:2447(epd)
#         1    0.000    0.000    0.000    0.000 __init__.py:282(__init__)
#       400    0.002    0.000    0.012    0.000 __init__.py:2863(parse_uci)
#       400    0.001    0.000    0.020    0.000 __init__.py:2887(push_uci)
#     31616    0.004    0.000    0.004    0.000 __init__.py:2937(is_en_passant)
#       400    0.000    0.000    0.000    0.000 __init__.py:2949(is_zeroing)
#      6133    0.006    0.000    0.008    0.000 __init__.py:2974(is_castling)
#      1905    0.002    0.000    0.002    0.000 __init__.py:2993(clean_castling_rights)
#      2802    0.006    0.000    0.008    0.000 __init__.py:3261(_slider_blockers)
#     37749    0.018    0.000    0.046    0.000 __init__.py:3280(_is_safe)
#       687    0.001    0.000    0.002    0.000 __init__.py:3293(_generate_evasions)
#     37992    0.023    0.000    0.159    0.000 __init__.py:3318(generate_legal_moves)
#        12    0.000    0.000    0.000    0.000 __init__.py:3338(generate_legal_ep)
#        74    0.000    0.000    0.000    0.000 __init__.py:3351(_attacked_for_king)
#       185    0.000    0.000    0.000    0.000 __init__.py:3352(<genexpr>)
#      1234    0.003    0.000    0.006    0.000 __init__.py:3354(generate_castling_moves)
#       906    0.001    0.000    0.001    0.000 __init__.py:3384(_from_chess960)
#       800    0.000    0.000    0.000    0.000 __init__.py:3399(_to_chess960)
#      3047    0.002    0.000    0.004    0.000 __init__.py:340(get_verbosity)
#      6094    0.003    0.000    0.108    0.000 __init__.py:345(set_verbosity)
#        24    0.000    0.000    0.000    0.000 __init__.py:35(populate_deserializable_objects)
#      1200    0.000    0.000    0.000    0.000 __init__.py:3540(__init__)
#      1200    0.001    0.000    0.001    0.000 __init__.py:3550(__iter__)
#         1    0.000    0.000    0.000    0.000 __init__.py:358(getMessage)
#       201    0.000    0.000    0.000    0.000 __init__.py:3641(__init__)
#     12864    0.003    0.000    0.003    0.000 __init__.py:3655(__contains__)
#      1688    0.001    0.000    0.001    0.000 __init__.py:377(between)
#       201    0.000    0.000    0.000    0.000 __init__.py:3804(__bool__)
#     69556    0.010    0.000    0.010    0.000 __init__.py:390(__init__)
#     24517    0.009    0.000    0.021    0.000 __init__.py:394(symbol)
#         1    0.000    0.000    0.000    0.000 __init__.py:421(usesTime)
#     41248    0.030    0.000    0.048    0.000 __init__.py:428(from_symbol)
#         1    0.000    0.000    0.000    0.000 __init__.py:429(_format)
#         1    0.000    0.000    0.000    0.000 __init__.py:43(normalize_encoding)
#         1    0.000    0.000    0.000    0.000 __init__.py:432(format)
#        57    0.000    0.000    0.000    0.000 __init__.py:437(_make)
#     38697    0.008    0.000    0.008    0.000 __init__.py:446(__init__)
#        57    0.000    0.000    0.000    0.000 __init__.py:447(_replace)
#     34388    0.014    0.000    0.020    0.000 __init__.py:452(uci)
#       112    0.000    0.000    0.000    0.000 __init__.py:460(_asdict)
#     36634    0.006    0.000    0.006    0.000 __init__.py:473(__bool__)
#        77    0.000    0.000    0.000    0.000 __init__.py:476(__eq__)
#     34388    0.008    0.000    0.027    0.000 __init__.py:489(__str__)
#     24673    0.008    0.000    0.010    0.000 __init__.py:49(piece_symbol)
#       400    0.002    0.000    0.002    0.000 __init__.py:495(from_uci)
#         3    0.000    0.000    0.000    0.000 __init__.py:547(__init__)
#         4    0.000    0.000    0.000    0.000 __init__.py:55(__getattr__)
#         5    0.000    0.000    0.000    0.000 __init__.py:557(_reset_board)
#         5    0.000    0.000    0.000    0.000 __init__.py:571(reset_board)
#      2205    0.003    0.000    0.003    0.000 __init__.py:575(_clear_board)
#         2    0.000    0.000    0.000    0.000 __init__.py:581(__init__)
#      2412    0.001    0.000    0.001    0.000 __init__.py:593(pieces_mask)
#        14    0.000    0.000    0.000    0.000 __init__.py:595(__missing__)
#     89856    0.029    0.000    0.049    0.000 __init__.py:617(piece_at)
#    132707    0.025    0.000    0.025    0.000 __init__.py:627(piece_type_at)
#         1    0.000    0.000    0.000    0.000 __init__.py:628(usesTime)
#         1    0.000    0.000    0.000    0.000 __init__.py:634(formatMessage)
#         2    0.000    0.000    0.000    0.000 __init__.py:649(update)
#         1    0.000    0.000    0.000    0.000 __init__.py:650(format)
#      2478    0.001    0.000    0.002    0.000 __init__.py:656(king)
#      7689    0.008    0.000    0.008    0.000 __init__.py:667(attacks_mask)
#      9009    0.017    0.000    0.017    0.000 __init__.py:697(_attackers_mask)
#         1    0.000    0.000    0.000    0.000 __init__.py:70(search_function)
#      8898    0.004    0.000    0.020    0.000 __init__.py:715(attackers_mask)
#      6096    0.002    0.000    0.016    0.000 __init__.py:718(is_attacked_by)
#         2    0.000    0.000    0.000    0.000 __init__.py:791(filter)
#     42051    0.017    0.000    0.025    0.000 __init__.py:793(_remove_piece_at)
#     41649    0.026    0.000    0.050    0.000 __init__.py:829(_set_piece_at)
#       402    0.013    0.000    0.035    0.000 __init__.py:867(board_fen)
#         2    0.000    0.000    0.000    0.000 __init__.py:896(acquire)
#      2202    0.078    0.000    0.188    0.000 __init__.py:897(_set_board_fen)
#         2    0.000    0.000    0.000    0.000 __init__.py:903(release)
#         1    0.000    0.000    0.000    0.000 __init__.py:916(format)
#         1    0.000    0.000    0.001    0.001 __init__.py:939(handle)
#        20    0.000    0.000    0.000    0.000 _asarray.py:14(asarray)
#       249    0.000    0.000    0.000    0.000 _collections_abc.py:262(__subclasshook__)
#         9    0.000    0.000    0.000    0.000 _collections_abc.py:283(__subclasshook__)
#       174    0.000    0.000    0.000    0.000 _collections_abc.py:315(__subclasshook__)
#        18    0.000    0.000    0.000    0.000 _collections_abc.py:381(__subclasshook__)
#      1081    0.000    0.000    0.000    0.000 _collections_abc.py:409(__subclasshook__)
#      1791    0.001    0.000    0.004    0.000 _collections_abc.py:759(get)
#      1232    0.001    0.000    0.002    0.000 _collections_abc.py:766(__contains__)
#      1175    0.001    0.000    0.001    0.000 _collections_abc.py:778(items)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:78(_check_methods)
#      1175    0.000    0.000    0.000    0.000 _collections_abc.py:801(__init__)
#      4868    0.007    0.000    0.009    0.000 _collections_abc.py:848(__iter__)
#        94    0.000    0.000    0.001    0.000 _collections_abc.py:932(update)
#        87    0.000    0.000    0.000    0.000 _collections_abc.py:950(setdefault)
#       104    0.000    0.000    0.000    0.000 _collections_abc.py:979(__iter__)
#      9141    0.001    0.000    0.001    0.000 _flagvalues.py:149(_flags)
#      3047    0.001    0.000    0.002    0.000 _flagvalues.py:469(__getitem__)
#      6094    0.004    0.000    0.106    0.000 _flagvalues.py:501(__setattr__)
#      6094    0.011    0.000    0.102    0.000 _flagvalues.py:506(_set_attributes)
#      6094    0.003    0.000    0.004    0.000 _flagvalues.py:535(_assert_validators)
#        42    0.000    0.000    0.000    0.000 _weakrefset.py:117(update)
#       540    0.000    0.000    0.000    0.000 _weakrefset.py:17(__init__)
#       540    0.000    0.000    0.000    0.000 _weakrefset.py:21(__enter__)
#       540    0.000    0.000    0.000    0.000 _weakrefset.py:27(__exit__)
#       145    0.000    0.000    0.000    0.000 _weakrefset.py:37(__init__)
#        40    0.000    0.000    0.000    0.000 _weakrefset.py:39(_remove)
#       173    0.000    0.000    0.000    0.000 _weakrefset.py:53(_commit_removals)
#       332    0.000    0.000    0.000    0.000 _weakrefset.py:59(__iter__)
#        80    0.000    0.000    0.000    0.000 _weakrefset.py:82(add)
# 32354/30643    0.007    0.000    0.028    0.000 abc.py:100(__subclasscheck__)
#     34156    0.009    0.000    0.063    0.000 abc.py:96(__instancecheck__)
#        32    0.000    0.000    0.012    0.000 activations.py:273(relu)
#         8    0.000    0.000    0.000    0.000 activations.py:459(linear)
#        30    0.000    0.000    0.000    0.000 activations.py:480(serialize)
#        10    0.000    0.000    0.000    0.000 activations.py:519(deserialize)
#        16    0.000    0.000    0.000    0.000 activations.py:562(get)
#      28/8    0.000    0.000    0.000    0.000 activity.py:136(referenced)
#    238/92    0.001    0.000    0.003    0.000 activity.py:147(copy_from)
#     78/21    0.000    0.000    0.002    0.000 activity.py:161(copy_of)
#     52/14    0.000    0.000    0.000    0.000 activity.py:172(merge_from)
#       285    0.001    0.000    0.001    0.000 activity.py:186(finalize)
#        21    0.000    0.000    0.000    0.000 activity.py:208(mark_param)
#         7    0.000    0.000    0.000    0.000 activity.py:219(__init__)
#        28    0.000    0.000    0.000    0.000 activity.py:227(__init__)
#        14    0.000    0.000    0.000    0.000 activity.py:241(__init__)
#        84    0.000    0.000    0.000    0.000 activity.py:252(_in_constructor)
#       447    0.001    0.000    0.003    0.000 activity.py:271(_track_symbol)
#       285    0.000    0.000    0.001    0.000 activity.py:328(_enter_scope)
#       285    0.000    0.000    0.001    0.000 activity.py:331(_exit_scope)
#       283    0.000    0.000    0.002    0.000 activity.py:337(_exit_and_record_scope)
#        99    0.000    0.000    0.012    0.000 activity.py:342(_process_statement)
#         7    0.000    0.000    0.000    0.000 activity.py:357(visit_ImportFrom)
#         7    0.000    0.000    0.000    0.000 activity.py:379(visit_Expr)
#         2    0.000    0.000    0.000    0.000 activity.py:382(visit_Raise)
#        14    0.000    0.000    0.003    0.000 activity.py:385(visit_Return)
#        52    0.000    0.000    0.006    0.000 activity.py:388(visit_Assign)
#       356    0.000    0.000    0.003    0.000 activity.py:417(visit_Name)
#         7    0.000    0.000    0.000    0.000 activity.py:423(visit_alias)
#     84/70    0.000    0.000    0.003    0.000 activity.py:436(visit_Attribute)
#         7    0.000    0.000    0.000    0.000 activity.py:444(visit_Subscript)
#     90/70    0.000    0.000    0.007    0.000 activity.py:461(visit_Call)
#        14    0.000    0.000    0.001    0.000 activity.py:471(_process_block_node)
#         7    0.000    0.000    0.005    0.001 activity.py:477(_process_parallel_blocks)
#         7    0.000    0.000    0.002    0.000 activity.py:493(_process_comprehension)
#         7    0.000    0.000    0.002    0.000 activity.py:510(visit_comprehension)
#         7    0.000    0.000    0.002    0.000 activity.py:517(visit_DictComp)
#       112    0.000    0.000    0.000    0.000 activity.py:548(_visit_node_list)
#       112    0.000    0.000    0.000    0.000 activity.py:549(<listcomp>)
#        14    0.000    0.000    0.000    0.000 activity.py:551(_visit_arg_annotations)
#        28    0.000    0.000    0.001    0.000 activity.py:559(_visit_arg_declarations)
#        14    0.000    0.000    0.019    0.001 activity.py:569(visit_FunctionDef)
#     17/12    0.000    0.000    0.014    0.001 activity.py:649(visit_With)
#        17    0.000    0.000    0.004    0.000 activity.py:655(visit_withitem)
#         7    0.000    0.000    0.005    0.001 activity.py:658(visit_If)
#         2    0.000    0.000    0.000    0.000 activity.py:697(visit_ExceptHandler)
#        14    0.000    0.000    0.020    0.001 activity.py:708(resolve)
#       377    0.001    0.000    0.002    0.000 activity.py:98(__init__)
#         2    0.000    0.000    0.000    0.000 adam.py:233(get_config)
#         1    0.000    0.000    0.000    0.000 adam.py:97(__init__)
#        10    0.000    0.000    0.000    0.000 advanced_activations.py:28(get_globals)
#       141    0.000    0.000    0.000    0.000 ag_ctx.py:32(_control_ctx)
#         9    0.000    0.000    0.000    0.000 ag_ctx.py:38(control_status_ctx)
#        44    0.000    0.000    0.000    0.000 ag_ctx.py:68(__init__)
#        44    0.000    0.000    0.000    0.000 ag_ctx.py:72(__enter__)
#        44    0.000    0.000    0.000    0.000 ag_ctx.py:80(__exit__)
#        24    0.000    0.000    0.000    0.000 ag_logging.py:114(get_verbosity)
#        24    0.000    0.000    0.000    0.000 ag_logging.py:121(has_verbosity)
#        19    0.000    0.000    0.000    0.000 ag_logging.py:138(log)
#      4712    0.002    0.000    0.004    0.000 anno.py:127(getanno)
#     16151    0.006    0.000    0.011    0.000 anno.py:134(hasanno)
#      2758    0.002    0.000    0.004    0.000 anno.py:138(setanno)
#      6228    0.002    0.000    0.006    0.000 anno.py:156(copyanno)
#         2    0.000    0.000    0.001    0.000 anno.py:165(dup)
#         1    0.000    0.000    0.000    0.000 anno.py:40(of)
#         3    0.000    0.000    0.000    0.000 api.py:154(__init__)
#         3    0.000    0.000    0.000    0.000 api.py:161(get_effective_source_map)
#         2    0.000    0.000    0.000    0.000 api.py:199(get_transformed_name)
#         2    0.000    0.000    0.000    0.000 api.py:202(get_extra_locals)
#         3    0.000    0.000    0.000    0.000 api.py:225(get_caching_key)
#         2    0.000    0.000    0.010    0.005 api.py:228(initial_analysis)
#         2    0.000    0.000    0.092    0.046 api.py:241(transform_ast)
#         3    0.000    0.000    0.144    0.048 api.py:266(_convert_actual)
#         9    0.000    0.000    0.000    0.000 api.py:297(is_autograph_artifact)
#       9/3    0.000    0.000    0.183    0.061 api.py:301(converted_call)
#         5    0.000    0.000    0.037    0.007 api.py:455(_call_unconverted)
#     30287    0.032    0.000    0.621    0.000 array_ops.py:1113(strided_slice)
#     90861    0.063    0.000    2.544    0.000 array_ops.py:1364(stack)
#         2    0.000    0.000    0.001    0.000 array_ops.py:1429(_autopacking_helper)
#         2    0.000    0.000    0.000    0.000 array_ops.py:1443(<genexpr>)
#         2    0.000    0.000    0.000    0.000 array_ops.py:1478(_get_dtype_from_nested_lists)
#     90879    0.079    0.000    0.342    0.000 array_ops.py:1514(_should_not_autopack)
#    181864    0.038    0.000    0.038    0.000 array_ops.py:1520(<genexpr>)
#     90879    0.034    0.000    0.376    0.000 array_ops.py:1524(_autopacking_conversion_function)
#        14    0.000    0.000    0.000    0.000 array_ops.py:202(fill)
#       106    0.000    0.000    0.021    0.000 array_ops.py:246(identity)
#        14    0.000    0.000    0.002    0.000 array_ops.py:2914(wrapped)
#        14    0.000    0.000    0.001    0.000 array_ops.py:2922(zeros)
#        16    0.000    0.000    0.007    0.000 array_ops.py:3237(placeholder)
#         2    0.000    0.000    0.001    0.000 array_ops.py:4585(where)
#       409    0.001    0.000    0.053    0.000 array_ops.py:61(reshape)
#     30287    0.015    0.000    0.089    0.000 array_ops.py:876(_check_index)
#     30287    0.305    0.000    4.648    0.000 array_ops.py:896(_slice_helper)
#         1    0.000    0.000    0.000    0.000 ascii.py:41(getregentry)
#      10/2    0.000    0.000    0.002    0.001 ast.py:1003(_function_helper)
#       3/2    0.000    0.000    0.001    0.001 ast.py:1064(visit_With)
#         1    0.000    0.000    0.000    0.000 ast.py:1076(_str_literal_helper)
#        60    0.000    0.000    0.000    0.000 ast.py:1082(escape_char)
#         1    0.000    0.000    0.000    0.000 ast.py:1096(<listcomp>)
#         2    0.000    0.000    0.000    0.000 ast.py:1106(<lambda>)
#         1    0.000    0.000    0.000    0.000 ast.py:1114(_write_str_avoiding_backslashes)
#       109    0.000    0.000    0.000    0.000 ast.py:1188(visit_Name)
#         1    0.000    0.000    0.000    0.000 ast.py:1191(_write_docstring)
#        33    0.000    0.000    0.000    0.000 ast.py:1197(_write_constant)
#        33    0.000    0.000    0.000    0.000 ast.py:1211(visit_Constant)
#         1    0.000    0.000    0.000    0.000 ast.py:1245(visit_DictComp)
#         1    0.000    0.000    0.000    0.000 ast.py:1253(visit_comprehension)
#        11    0.000    0.000    0.000    0.000 ast.py:1308(visit_Tuple)
#         1    0.000    0.000    0.000    0.000 ast.py:1395(visit_Compare)
#     46/39    0.000    0.000    0.000    0.000 ast.py:1420(visit_Attribute)
#     44/19    0.000    0.000    0.001    0.000 ast.py:1431(visit_Call)
#         1    0.000    0.000    0.000    0.000 ast.py:1449(visit_Subscript)
#         1    0.000    0.000    0.000    0.000 ast.py:1450(is_simple_tuple)
#         3    0.000    0.000    0.000    0.000 ast.py:1486(visit_arg)
#        10    0.000    0.000    0.000    0.000 ast.py:1492(visit_arguments)
#        14    0.000    0.000    0.000    0.000 ast.py:1543(visit_keyword)
#         4    0.000    0.000    0.000    0.000 ast.py:1559(visit_alias)
#         3    0.000    0.000    0.000    0.000 ast.py:1564(visit_withitem)
#         3    0.000    0.000    0.002    0.001 ast.py:1570(unparse)
#       422    0.001    0.000    0.001    0.000 ast.py:175(copy_location)
#         3    0.000    0.000    0.002    0.001 ast.py:192(fix_missing_locations)
#     508/3    0.001    0.000    0.002    0.001 ast.py:200(_fix)
#     31139    0.006    0.000    0.008    0.000 ast.py:244(iter_fields)
#      1332    0.001    0.000    0.001    0.000 ast.py:256(iter_child_nodes)
#        61    0.000    0.000    0.002    0.000 ast.py:33(parse)
#       164    0.000    0.000    0.001    0.000 ast.py:369(walk)
#  10643/94    0.008    0.000    0.111    0.001 ast.py:403(visit)
#   1213/49    0.002    0.000    0.010    0.000 ast.py:409(generic_visit)
#       812    0.001    0.000    0.004    0.000 ast.py:419(visit_Constant)
#  7058/177    0.012    0.000    0.081    0.000 ast.py:477(generic_visit)
#         2    0.000    0.000    0.000    0.000 ast.py:659(next)
#         3    0.000    0.000    0.000    0.000 ast.py:675(__init__)
#     14/12    0.000    0.000    0.000    0.000 ast.py:683(interleave)
#        11    0.000    0.000    0.000    0.000 ast.py:695(items_view)
#         4    0.000    0.000    0.000    0.000 ast.py:703(<lambda>)
#        65    0.000    0.000    0.000    0.000 ast.py:705(maybe_newline)
#        55    0.000    0.000    0.000    0.000 ast.py:710(fill)
#       633    0.000    0.000    0.000    0.000 ast.py:716(write)
#        34    0.000    0.000    0.000    0.000 ast.py:729(block)
#       134    0.000    0.000    0.000    0.000 ast.py:743(delimit)
#         1    0.000    0.000    0.000    0.000 ast.py:752(delimit_if)
#         1    0.000    0.000    0.000    0.000 ast.py:758(require_parens)
#         1    0.000    0.000    0.000    0.000 ast.py:762(get_precedence)
#        95    0.000    0.000    0.000    0.000 ast.py:765(set_precedence)
#        10    0.000    0.000    0.000    0.000 ast.py:769(get_raw_docstring)
#        34    0.000    0.000    0.000    0.000 ast.py:785(get_type_comment)
#     352/3    0.000    0.000    0.002    0.001 ast.py:790(traverse)
#         3    0.000    0.000    0.002    0.001 ast.py:797(visit)
#      10/2    0.000    0.000    0.002    0.001 ast.py:804(_write_docstring_and_traverse_body)
#         1    0.000    0.000    0.000    0.000 ast.py:828(visit_Expr)
#         2    0.000    0.000    0.000    0.000 ast.py:844(visit_ImportFrom)
#         2    0.000    0.000    0.000    0.000 ast.py:850(<lambda>)
#        21    0.000    0.000    0.001    0.000 ast.py:852(visit_Assign)
#         7    0.000    0.000    0.000    0.000 ast.py:877(visit_Return)
#         1    0.000    0.000    0.000    0.000 ast.py:883(visit_Pass)
#         3    0.000    0.000    0.000    0.000 ast.py:907(visit_Nonlocal)
#         2    0.000    0.000    0.000    0.000 ast.py:935(visit_Raise)
#         2    0.000    0.000    0.000    0.000 ast.py:947(visit_Try)
#         2    0.000    0.000    0.000    0.000 ast.py:962(visit_ExceptHandler)
#      10/2    0.000    0.000    0.002    0.001 ast.py:997(visit_FunctionDef)
#       295    0.000    0.000    0.003    0.000 ast3.py:173(visit_Name)
#        12    0.000    0.000    0.000    0.000 ast3.py:183(visit_arg)
#         4    0.000    0.000    0.000    0.000 ast3.py:198(visit_ExceptHandler)
#        23    0.000    0.000    0.000    0.000 ast3.py:272(_make_arg)
#       109    0.000    0.000    0.001    0.000 ast3.py:288(visit_Name)
#         2    0.000    0.000    0.000    0.000 ast3.py:296(visit_ExceptHandler)
#        10    0.000    0.000    0.000    0.000 ast3.py:416(visit_arguments)
#        10    0.000    0.000    0.000    0.000 ast3.py:418(<listcomp>)
#        10    0.000    0.000    0.000    0.000 ast3.py:424(<listcomp>)
#        10    0.000    0.000    0.000    0.000 ast3.py:425(<listcomp>)
#        61    0.000    0.000    0.010    0.000 ast3.py:436(ast_to_gast)
#         3    0.000    0.000    0.003    0.001 ast3.py:440(gast_to_ast)
#       519    0.002    0.000    0.003    0.000 ast_util.py:283(parallel_walk)
#       118    0.000    0.000    0.000    0.000 ast_util.py:33(__init__)
#  2623/118    0.006    0.000    0.015    0.000 ast_util.py:37(copy)
#    338/51    0.000    0.000    0.013    0.000 ast_util.py:41(<listcomp>)
#         7    0.000    0.000    0.000    0.000 ast_util.py:43(<genexpr>)
#       118    0.000    0.000    0.016    0.000 ast_util.py:63(copy_clean)
#   739/131    0.000    0.000    0.013    0.000 astn.py:11(<listcomp>)
#   1360/64    0.003    0.000    0.013    0.000 astn.py:17(generic_visit)
#  3668/137    0.002    0.000    0.013    0.000 astn.py:9(_visit)
#      1094    0.001    0.000    0.001    0.000 auto_control_deps.py:132(op_is_stateful)
#       547    0.000    0.000    0.002    0.000 auto_control_deps.py:143(collective_manager_ids_from_op)
#        41    0.000    0.000    0.000    0.000 auto_control_deps.py:185(__init__)
#        41    0.000    0.000    0.015    0.000 auto_control_deps.py:193(mark_as_return)
#        41    0.000    0.000    0.000    0.000 auto_control_deps.py:236(__enter__)
#        41    0.004    0.000    0.056    0.001 auto_control_deps.py:312(__exit__)
#       120    0.000    0.000    0.000    0.000 auto_control_deps.py:390(<genexpr>)
#       751    0.002    0.000    0.035    0.000 auto_control_deps.py:599(_get_resource_inputs)
#       120    0.000    0.000    0.000    0.000 auto_control_deps_utils.py:105(<genexpr>)
#       458    0.000    0.000    0.001    0.000 auto_control_deps_utils.py:112(<genexpr>)
#        46    0.001    0.000    0.005    0.000 auto_control_deps_utils.py:36(get_read_only_resource_input_indices_graph)
#       115    0.000    0.000    0.000    0.000 auto_control_deps_utils.py:54(<listcomp>)
#       115    0.000    0.000    0.002    0.000 auto_control_deps_utils.py:63(_get_read_only_resource_input_indices_op)
#        70    0.000    0.000    0.000    0.000 auto_control_deps_utils.py:66(<listcomp>)
#       547    0.002    0.000    0.026    0.000 auto_control_deps_utils.py:89(get_read_write_resource_inputs)
#        98    0.000    0.000    0.000    0.000 autocast_variable.py:538(__init__)
#        98    0.000    0.000    0.000    0.000 autocast_variable.py:543(__enter__)
#        98    0.000    0.000    0.000    0.000 autocast_variable.py:547(__exit__)
#        24    0.000    0.000    0.000    0.000 backend.py:1086(track_variable)
#         4    0.000    0.000    0.000    0.000 backend.py:1095(observe_object_name)
#        14    0.000    0.000    0.000    0.000 backend.py:1100(unique_object_name)
#         2    0.000    0.000    0.000    0.000 backend.py:1267(placeholder)
#        30    0.000    0.000    0.000    0.000 backend.py:1410(int_shape)
#         2    0.000    0.000    0.000    0.000 backend.py:148(backend)
#        10    0.000    0.000    0.000    0.000 backend.py:1501(dtype_numpy)
#        10    0.000    0.000    0.000    0.000 backend.py:1723(use_generator_for_rng)
#        10    0.000    0.000    0.000    0.000 backend.py:1746(__init__)
#        10    0.000    0.000    0.000    0.000 backend.py:1751(_maybe_init)
#        10    0.000    0.000    0.000    0.000 backend.py:1796(make_legacy_seed)
#        10    0.000    0.000    0.013    0.001 backend.py:1825(random_uniform)
#         2    0.000    0.000    0.000    0.000 backend.py:195(get_uid)
#        13    0.000    0.000    0.000    0.000 backend.py:350(global_learning_phase_is_set)
#         1    0.000    0.000    0.002    0.002 backend.py:3854(batch_get_value)
#         1    0.000    0.000    0.002    0.002 backend.py:3870(<listcomp>)
#         1    0.000    0.000    0.002    0.002 backend.py:3918(batch_set_value)
#        21    0.000    0.000    0.000    0.000 backend.py:421(deprecated_internal_set_learning_phase)
#        32    0.000    0.000    0.012    0.000 backend.py:4822(relu)
#        42    0.000    0.000    0.001    0.000 backend.py:485(deprecated_internal_learning_phase_scope)
#       8/4    0.000    0.000    0.000    0.000 backend.py:6600(_is_tpu_strategy_class)
#         8    0.000    0.000    0.000    0.000 backend.py:6601(<lambda>)
#         4    0.000    0.000    0.000    0.000 backend.py:6607(is_tpu_strategy)
#       136    0.000    0.000    0.000    0.000 backend.py:738(get_graph)
#        14    0.000    0.000    0.000    0.000 backend.py:807(get_default_graph_uid_map)
#        12    0.000    0.000    0.000    0.000 backend.py:994(name_scope)
#         8    0.000    0.000    0.000    0.000 backend_config.py:113(image_data_format)
#        50    0.000    0.000    0.000    0.000 backend_config.py:64(floatx)
#       708    0.001    0.000    0.001    0.000 backprop.py:167(_must_record_gradient)
#       240    0.000    0.000    0.000    0.000 base.py:1021(_gather_saveables_for_checkpoint)
#       588    0.000    0.000    0.000    0.000 base.py:1054(_list_extra_dependencies_for_serialization)
#        15    0.000    0.000    0.000    0.000 base.py:1084(_list_functions_for_serialization)
#        80    0.000    0.000    0.000    0.000 base.py:1102(_map_resources)
#         2    0.000    0.000    0.000    0.000 base.py:135(__init__)
#         1    0.000    0.000    0.000    0.000 base.py:140(restore)
# 1815/1743    0.002    0.000    0.014    0.000 base.py:526(_method_wrapper)
#       315    0.000    0.000    0.000    0.000 base.py:617(_setattr_tracking)
#       592    0.000    0.000    0.001    0.000 base.py:623(_setattr_tracking)
#        19    0.000    0.000    0.000    0.000 base.py:627(_update_uid)
#        19    0.000    0.000    0.000    0.000 base.py:635(_unconditional_checkpoint_dependencies)
#        19    0.000    0.000    0.000    0.000 base.py:639(_unconditional_dependency_names)
#        19    0.000    0.000    0.000    0.000 base.py:643(_name_based_restores)
#      1132    0.000    0.000    0.001    0.000 base.py:651(_maybe_initialize_trackable)
#        18    0.000    0.000    0.000    0.000 base.py:695(_object_identifier)
#       678    0.000    0.000    0.000    0.000 base.py:721(_checkpoint_dependencies)
#       180    0.000    0.000    0.000    0.000 base.py:734(_deferred_dependencies)
#       161    0.000    0.000    0.000    0.000 base.py:749(_lookup_dependency)
#        24    0.000    0.000    0.023    0.001 base.py:763(_add_variable_with_custom_getter)
#        24    0.000    0.000    0.000    0.000 base.py:834(_preload_simple_restoration)
#       161    0.000    0.000    0.003    0.000 base.py:870(_track_trackable)
#       137    0.000    0.000    0.001    0.000 base.py:924(_handle_deferred_dependencies)
#       100    0.000    0.000    0.000    0.000 base_layer.py:1026(<genexpr>)
#        12    0.000    0.000    0.067    0.006 base_layer.py:1094(_functional_construction_call)
#        24    0.000    0.000    0.000    0.000 base_layer.py:1098(<genexpr>)
#        50    0.000    0.000    0.000    0.000 base_layer.py:1177(_set_training_mode)
#        50    0.000    0.000    0.000    0.000 base_layer.py:1220(_autographed_call)
#        50    0.000    0.000    0.000    0.000 base_layer.py:1234(dtype)
#       511    0.000    0.000    0.000    0.000 base_layer.py:1244(name)
#        58    0.000    0.000    0.000    0.000 base_layer.py:1249(supports_masking)
#         6    0.000    0.000    0.000    0.000 base_layer.py:1254(supports_masking)
#        96    0.000    0.000    0.000    0.000 base_layer.py:1258(dynamic)
#       213    0.000    0.000    0.000    0.000 base_layer.py:1261(<genexpr>)
#        31    0.000    0.000    0.000    0.000 base_layer.py:1263(stateful)
#        83    0.000    0.000    0.000    0.000 base_layer.py:1266(<genexpr>)
#         2    0.000    0.000    0.000    0.000 base_layer.py:1268(stateful)
#       450    0.000    0.000    0.000    0.000 base_layer.py:1272(trainable)
#        54    0.000    0.000    0.000    0.000 base_layer.py:1291(activity_regularizer)
#       105    0.000    0.000    0.000    0.000 base_layer.py:1301(input_spec)
#        22    0.000    0.000    0.000    0.000 base_layer.py:1336(input_spec)
#       180    0.000    0.000    0.001    0.000 base_layer.py:1347(trainable_weights)
#       180    0.000    0.000    0.001    0.000 base_layer.py:1362(non_trainable_weights)
#       145    0.000    0.000    0.001    0.000 base_layer.py:1383(weights)
#        10    0.000    0.000    0.000    0.000 base_layer.py:1392(updates)
#        28    0.000    0.000    0.000    0.000 base_layer.py:1402(losses)
#        24    0.000    0.000    0.000    0.000 base_layer.py:1464(add_loss)
#         1    0.000    0.000    0.000    0.000 base_layer.py:1584(_clear_losses)
#        15    0.000    0.000    0.000    0.000 base_layer.py:1594(metrics)
#         1    0.000    0.000    0.002    0.002 base_layer.py:1778(set_weights)
#         1    0.000    0.000    0.002    0.002 base_layer.py:1864(get_weights)
#         8    0.000    0.000    0.000    0.000 base_layer.py:1908(finalize_state)
#        10    0.000    0.000    0.000    0.000 base_layer.py:1996(input_mask)
#        10    0.000    0.000    0.000    0.000 base_layer.py:2018(output_mask)
#        20    0.000    0.000    0.000    0.000 base_layer.py:2118(input)
#        18    0.000    0.000    0.000    0.000 base_layer.py:2137(output)
#         9    0.000    0.000    0.000    0.000 base_layer.py:2156(input_shape)
#         7    0.000    0.000    0.000    0.000 base_layer.py:2177(<listcomp>)
#         9    0.000    0.000    0.000    0.000 base_layer.py:2211(output_shape)
#         7    0.000    0.000    0.000    0.000 base_layer.py:2231(<listcomp>)
#        12    0.000    0.000    0.000    0.000 base_layer.py:2243(inbound_nodes)
#        10    0.000    0.000    0.000    0.000 base_layer.py:2249(outbound_nodes)
#     61/47    0.000    0.000    0.001    0.000 base_layer.py:2290(variables)
#     38/24    0.000    0.000    0.000    0.000 base_layer.py:2305(trainable_variables)
#     38/24    0.000    0.000    0.000    0.000 base_layer.py:2310(non_trainable_variables)
#       328    0.000    0.000    0.000    0.000 base_layer.py:2319(_inbound_nodes)
#        32    0.000    0.000    0.000    0.000 base_layer.py:2328(_outbound_nodes)
#        18    0.000    0.000    0.000    0.000 base_layer.py:2337(_set_dtype_policy)
#        10    0.000    0.000    0.000    0.000 base_layer.py:2374(dtype_policy)
#        10    0.000    0.000    0.000    0.000 base_layer.py:2382(compute_dtype)
#        16    0.000    0.000    0.000    0.000 base_layer.py:2404(_compute_dtype)
#        10    0.000    0.000    0.000    0.000 base_layer.py:2409(variable_dtype)
#        60    0.000    0.000    0.000    0.000 base_layer.py:2414(_maybe_cast_inputs)
#        60    0.000    0.000    0.000    0.000 base_layer.py:2442(_should_cast_single_input)
#        28    0.000    0.000    0.000    0.000 base_layer.py:2458(_dtype)
#        62    0.000    0.000    0.001    0.000 base_layer.py:2470(_name_scope)
#        16    0.000    0.000    0.000    0.000 base_layer.py:2486(_init_set_name)
#        12    0.000    0.000    0.000    0.000 base_layer.py:2523(_handle_activity_regularization)
#        30    0.000    0.000    0.000    0.000 base_layer.py:2538(_set_mask_metadata)
#        40    0.000    0.000    0.000    0.000 base_layer.py:2549(<genexpr>)
#         2    0.000    0.000    0.000    0.000 base_layer.py:2570(_set_mask_keras_history_checked)
#        62    0.000    0.000    0.000    0.000 base_layer.py:2576(_get_input_masks)
#        22    0.000    0.000    0.000    0.000 base_layer.py:2586(<listcomp>)
#        44    0.000    0.000    0.000    0.000 base_layer.py:2587(<genexpr>)
#        72    0.000    0.000    0.000    0.000 base_layer.py:2596(_call_arg_was_passed)
#        13    0.000    0.000    0.000    0.000 base_layer.py:2609(_get_call_arg_value)
#         1    0.000    0.000    0.000    0.000 base_layer.py:2619(_set_call_arg_value)
#        12    0.000    0.000    0.001    0.000 base_layer.py:2637(_set_connectivity_metadata)
#        12    0.000    0.000    0.000    0.000 base_layer.py:2642(<setcomp>)
#        30    0.000    0.000    0.000    0.000 base_layer.py:2659(_get_node_attribute_at_index)
#        12    0.000    0.000    0.025    0.002 base_layer.py:2695(_maybe_build)
#        24    0.000    0.000    0.000    0.000 base_layer.py:2710(<genexpr>)
#         3    0.000    0.000    0.000    0.000 base_layer.py:2751(_get_trainable_state)
#       494    0.001    0.000    0.002    0.000 base_layer.py:2768(_obj_reference_counts)
#       601    0.000    0.000    0.000    0.000 base_layer.py:2775(_maybe_create_attribute)
#       242    0.000    0.000    0.002    0.000 base_layer.py:2792(__delattr__)
#        18    0.000    0.000    0.000    0.000 base_layer.py:282(_get_cell_name)
# 4747/2936    0.005    0.000    0.012    0.000 base_layer.py:2836(__setattr__)
#         1    0.000    0.000    0.000    0.000 base_layer.py:2876(<genexpr>)
#        18    0.000    0.000    0.001    0.000 base_layer.py:289(_instrument_layer_creation)
#        50    0.000    0.000    0.000    0.000 base_layer.py:2895(<genexpr>)
#        10    0.000    0.000    0.000    0.000 base_layer.py:2899(<genexpr>)
#       360    0.001    0.000    0.001    0.000 base_layer.py:2909(_gather_children_attribute)
# ...
#        12    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.framework._op_def_registry.get}
#         1    0.002    0.002    0.002    0.002 {built-in method tensorflow.python.grappler._pywrap_tf_cluster.TF_NewCluster}
#         1    0.001    0.001    0.001    0.001 {built-in method tensorflow.python.grappler._pywrap_tf_cluster.TF_ShutdownCluster}
#         1    0.001    0.001    0.001    0.001 {built-in method tensorflow.python.grappler._pywrap_tf_optimizer.TF_OptimizeGraph}
#         2    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.lib.io._pywrap_file_io.HasAtomicMove}
#         4    0.006    0.001    0.006    0.001 {built-in method tensorflow.python.lib.io._pywrap_file_io.RecursivelyCreateDir}
#         2    0.010    0.005    0.010    0.005 {built-in method tensorflow.python.lib.io._pywrap_file_io.RenameFile}
#         1    0.002    0.002    0.002    0.002 {built-in method tensorflow.python.lib.io._pywrap_file_io.Stat}
#       214    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.platform._pywrap_tf2.is_enabled}
#         1    0.001    0.001    0.001    0.001 {built-in method tensorflow.python.saved_model.pywrap_saved_model.Save}
#        50    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_determinism.is_enabled}
#       256    0.001    0.000    0.001    0.000 {built-in method tensorflow.python.util._pywrap_utils.AssertSameStructure}
#     95915    0.145    0.000    0.148    0.000 {built-in method tensorflow.python.util._pywrap_utils.Flatten}
#       809    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsAttrs}
#       809    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsCompositeTensor}
#       777    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsMappingView}
#       809    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsMapping}
#       968    0.001    0.000    0.001    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsMutableMapping}
#       777    0.001    0.000    0.001    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsNamedtuple}
#      2019    0.001    0.000    0.001    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsSequenceOrComposite}
#      2689    0.001    0.000    0.001    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsSequence}
#         2    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsTensor}
#       793    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsTypeSpec}
#       859    0.007    0.000    0.007    0.000 {built-in method tensorflow.python.util._tf_stack.extract_stack_for_node}
#        83    0.000    0.000    0.000    0.000 {built-in method time.time}
#        19    0.000    0.000    0.000    0.000 {built-in method utcnow}
#        30    0.000    0.000    0.000    0.000 {function Config.__contains__ at 0x000002A984A1C5E0}
#         4    0.000    0.000    0.000    0.000 {function OptimizerV2.__dir__ at 0x000002AA57209820}
#      1562    0.004    0.000    0.004    0.000 {method 'ByteSize' of 'google.protobuf.pyext._message.CMessage' objects}
#        20    0.000    0.000    0.000    0.000 {method 'Clear' of 'google.protobuf.pyext._message.CMessage' objects}
#         7    0.000    0.000    0.000    0.000 {method 'ClearField' of 'google.protobuf.pyext._message.CMessage' objects}
#      2864    0.011    0.000    0.011    0.000 {method 'CopyFrom' of 'google.protobuf.pyext._message.CMessage' objects}
#      3300    0.001    0.000    0.001    0.000 {method 'HasField' of 'google.protobuf.pyext._message.CMessage' objects}
#         5    0.000    0.000    0.000    0.000 {method 'MergeFrom' of 'google.protobuf.pyext._message.CMessage' objects}
#       623    0.033    0.000    0.033    0.000 {method 'ParseFromString' of 'google.protobuf.pyext._message.CMessage' objects}
#      2545    0.016    0.000    0.016    0.000 {method 'SerializeToString' of 'google.protobuf.pyext._message.CMessage' objects}
#        14    0.000    0.000    0.000    0.000 {method 'SetInParent' of 'google.protobuf.pyext._message.CMessage' objects}
#       403    0.000    0.000    0.000    0.000 {method 'WhichOneof' of 'google.protobuf.pyext._message.CMessage' objects}
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_io._IOBase' objects}
#        13    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         8    0.001    0.000    0.001    0.000 {method '__exit__' of '_io._IOBase' objects}
#      3349    0.001    0.000    0.001    0.000 {method '__exit__' of '_thread.RLock' objects}
#        83    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#      1229    0.000    0.000    0.000    0.000 {method '__getitem__' of 'dict' objects}
#        71    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#    177909    0.022    0.000    0.022    0.000 {method '_datatype_enum' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#     45524    0.089    0.000    0.089    0.000 {method '_numpy_internal' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#        75    0.000    0.000    0.000    0.000 {method '_shape_tuple' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#      6157    0.001    0.000    0.001    0.000 {method 'acquire' of '_thread.RLock' objects}
#      2470    0.003    0.000    0.003    0.000 {method 'acquire' of '_thread.lock' objects}
#      1515    0.001    0.000    0.001    0.000 {method 'add' of 'google.protobuf.pyext._message.RepeatedCompositeContainer' objects}
#     11783    0.002    0.000    0.002    0.000 {method 'add' of 'set' objects}
#      1036    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        31    0.000    0.000    0.000    0.000 {method 'append' of 'google.protobuf.pyext._message.RepeatedCompositeContainer' objects}
#        45    0.000    0.000    0.000    0.000 {method 'append' of 'google.protobuf.pyext._message.RepeatedScalarContainer' objects}
#    316763    0.032    0.000    0.032    0.000 {method 'append' of 'list' objects}
#     14870    0.001    0.000    0.001    0.000 {method 'append' of 'xml.etree.ElementTree.Element' objects}
#        10    0.001    0.000    0.001    0.000 {method 'astype' of 'numpy.ndarray' objects}
#     59929    0.005    0.000    0.005    0.000 {method 'bit_length' of 'int' objects}
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#    140162    0.008    0.000    0.008    0.000 {method 'clear' of 'dict' objects}
#      4414    0.001    0.000    0.001    0.000 {method 'clear' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#      8438    0.001    0.000    0.001    0.000 {method 'close' of 'xml.etree.ElementTree.XMLParser' objects}
#        57    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#       288    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        20    0.002    0.000    0.002    0.000 {method 'copy' of 'numpy.ndarray' objects}
#      1428    0.000    0.000    0.000    0.000 {method 'copy' of 'set' objects}
#        26    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#        27    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#       760    0.002    0.000    0.002    0.000 {method 'decode' of 'bytes' objects}
#       201    0.001    0.000    0.001    0.000 {method 'detach' of '_io.TextIOWrapper' objects}
#         2    0.000    0.000    0.000    0.000 {method 'difference_update' of 'set' objects}
#        19    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        47    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#      2150    0.001    0.000    0.001    0.000 {method 'encode' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'end' of 're.Match' objects}
#       115    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 {method 'extend' of 'bytearray' objects}
#       161    0.000    0.000    0.000    0.000 {method 'extend' of 'collections.deque' objects}
#       607    0.001    0.000    0.001    0.000 {method 'extend' of 'google.protobuf.pyext._message.RepeatedCompositeContainer' objects}
#       119    0.000    0.000    0.000    0.000 {method 'extend' of 'google.protobuf.pyext._message.RepeatedScalarContainer' objects}
#      3502    0.001    0.000    0.001    0.000 {method 'extend' of 'list' objects}
#      8438    0.033    0.000    0.033    0.000 {method 'feed' of 'xml.etree.ElementTree.XMLParser' objects}
#        10    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
#       123    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#        45    0.000    0.000    0.000    0.000 {method 'findall' of 're.Pattern' objects}
#       182    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#    109489    0.014    0.000    0.015    0.000 {method 'get' of 'dict' objects}
#       711    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#       321    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#       201    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        45    0.000    0.000    0.000    0.000 {method 'group' of 're.Match' objects}
#        19    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#     42435    0.006    0.000    0.006    0.000 {method 'index' of 'list' objects}
#        28    0.000    0.000    0.000    0.000 {method 'index' of 'str' objects}
#      3047    0.001    0.000    0.001    0.000 {method 'insert' of 'list' objects}
#         8    0.000    0.000    0.000    0.000 {method 'isalnum' of 'str' objects}
#        16    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#      3260    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#        38    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#        60    0.000    0.000    0.000    0.000 {method 'isprintable' of 'str' objects}
#        12    0.000    0.000    0.000    0.000 {method 'issubset' of 'set' objects}
#     42522    0.003    0.000    0.003    0.000 {method 'isupper' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.generic' objects}
#         9    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#     15270    0.002    0.000    0.002    0.000 {method 'items' of 'dict' objects}
#     78632    0.011    0.000    0.011    0.000 {method 'items' of 'xml.etree.ElementTree.Element' objects}
#       201    0.000    0.000    0.000    0.000 {method 'iter' of 'xml.etree.ElementTree.Element' objects}
# 28668/28659    0.005    0.000    0.012    0.000 {method 'join' of 'str' objects}
#      1511    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         8    0.000    0.000    0.000    0.000 {method 'keys' of 'mappingproxy' objects}
#    141570    0.010    0.000    0.010    0.000 {method 'lower' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#      5450    0.006    0.000    0.006    0.000 {method 'match' of 're.Pattern' objects}
#       356    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#       201    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.deque' objects}
#      2146    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#     46989    0.013    0.000    0.013    0.000 {method 'pop' of 'list' objects}
#        80    0.000    0.000    0.000    0.000 {method 'popitem' of 'collections.OrderedDict' objects}
#       953    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'read' of '_io.BufferedReader' objects}
#         4    0.000    0.000    0.000    0.000 {method 'readline' of '_io.BufferedReader' objects}
#       137    0.000    0.000    0.000    0.000 {method 'readline' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 {method 'readlines' of '_io._IOBase' objects}
#        10    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      6157    0.001    0.000    0.001    0.000 {method 'release' of '_thread.RLock' objects}
#      1583    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#      3059    0.002    0.000    0.002    0.000 {method 'remove' of 'list' objects}
#       560    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#        19    0.000    0.000    0.000    0.000 {method 'replace' of 'datetime.datetime' objects}
#      3540    0.001    0.000    0.001    0.000 {method 'replace' of 'str' objects}
#       801    0.001    0.000    0.001    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#        13    0.000    0.000    0.000    0.000 {method 'rsplit' of 'str' objects}
#        41    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#       402    0.000    0.000    0.000    0.000 {method 'set' of 'xml.etree.ElementTree.Element' objects}
#        58    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#       119    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#      1452    0.000    0.000    0.000    0.000 {method 'span' of 're.Match' objects}
#      4550    0.003    0.000    0.003    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#      6216    0.001    0.000    0.001    0.000 {method 'startswith' of 'str' objects}
#      2232    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        95    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#       971    0.000    0.000    0.002    0.000 {method 'throw' of 'generator' objects}
#         6    0.000    0.000    0.000    0.000 {method 'to_bytes' of 'int' objects}
#        18    0.001    0.000    0.001    0.000 {method 'tobytes' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'translate' of 'bytearray' objects}
#       400    0.006    0.000    0.006    0.000 {method 'uniform' of 'numpy.random.mtrand.RandomState' objects}
#        95    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HASH' objects}
#      1590    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
# 3983/3885    0.001    0.000    0.001    0.000 {method 'update' of 'set' objects}
#     13194    0.002    0.000    0.002    0.000 {method 'upper' of 'str' objects}
#       974    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#      6987    0.001    0.000    0.001    0.000 {method 'values' of 'dict' objects}
#       274    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.FileIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#    244893    0.060    0.000    0.074    0.000 {method 'write' of '_io.TextIOWrapper' objects}
#
#
# None

# %%
# Try initializing a constant q value for all (state, action) pair. Since the probability of getting that initial q
# value from the model is zero (because q values are continuous) if we see the initial q value then it would mean we
# have not explored this (state, action) pair yet. So, if q value is the initial constant, take epsilon-greedy action with
# epsilon = 1 otherwise epsilon = 0.

# %%
def play():
    C.reset_to_initial_state()
    state = C.current_state
    states = [state]
    
    i = 0
    while not C.terminal:
        action = C.epsilon_greedy_action(state, 0)
        
        # if not i % 2:
        #     action = C.epsilon_greedy_action(state, 0)
        # else:
        #     while True:
        #         action = input(f'move {C.possible_actions(state)}')
        #         if action in C.possible_actions(state):
        #             break
                
        # time.sleep(0.1)
        # action = C.argmax_Q(state)
        state, _ = C.take_action(action)
        states.append(state)
        i += 1
        
        C.display_next_board(action)
    C.show_game(states=states)

# %%
play()
